# %%
# The archive now extracts directly into 'speech_commands_v0.02',
# meaning we no longer need the error-prone shutil.move loop that was here.
print('Extraction path is correctly set up.')
# Out:
# Extraction path is correctly set up.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

INPUT_SHAPE = (64, 32, 1)
NUM_CLASSES = 35

def build_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape, name='mel_spectrogram')
    x = inputs
    for filters in [32, 64, 128, 128]:
        x = layers.Conv2D(filters, (3, 3), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.MaxPooling2D((2, 2))(x)
        x = layers.Dropout(0.25)(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(num_classes, activation='softmax', name='probs')(x)
    model = keras.Model(inputs, outputs, name='SpeechCNN')
    return model

model = build_cnn(INPUT_SHAPE, NUM_CLASSES)
model.summary()
# Out:
# Model: "SpeechCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mel_spectrogram (InputLayer)    │ (None, 64, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 32, 32)     │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 16, 64)     │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 8, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 8, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 8, 128)     │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 8, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 16, 8, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 4, 128)      │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 8, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 4, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 4, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ probs (Dense)                   │ (None, 35)             │         8,995 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 283,331 (1.08 MB)
#  Trainable params: 282,627 (1.08 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
import os
import urllib.request
import tarfile

url = 'http://download.tensorflow.org/data/speech_commands_v0.02.tar.gz'
archive = 'speech_commands_v0.02.tar.gz'
extracted_dir = 'speech_commands_v0.02'

if not os.path.exists(archive):
    print('Downloading', url)
    urllib.request.urlretrieve(url, archive)
else:
    print('Archive already downloaded.')

if not os.path.exists(os.path.join(extracted_dir, 'validation_list.txt')):
    print('Extracting...')
    os.makedirs(extracted_dir, exist_ok=True)
    with tarfile.open(archive, 'r:gz') as tar:
        tar.extractall(path=extracted_dir)
    print('Extraction complete')
else:
    print('Files already extracted to', extracted_dir)
# Out:
# Downloading http://download.tensorflow.org/data/speech_commands_v0.02.tar.gz
# Files already extracted to speech_commands_v0.02

# %%
# %pip install tqdm scikit-learn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\JUSTINELUISCALAGUAS\AppData\Local\Python\pythoncore-3.11-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\JUSTINELUISCALAGUAS\AppData\Local\Python\pythoncore-3.11-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys

print('Python version:', sys.version)
if sys.version_info >= (3, 14):
    print('TensorFlow is not available for Python 3.14 in this environment.')
    print('Please switch the notebook kernel to Python 3.11 or 3.12 and rerun this cell.')
else:
    get_ipython().run_line_magic('pip', 'install tensorflow -q')
# Out:
# Python version: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wheel.exe is installed in 'c:\Users\JUSTINELUISCALAGUAS\AppData\Local\Python\pythoncore-3.11-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\JUSTINELUISCALAGUAS\AppData\Local\Python\pythoncore-3.11-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\JUSTINELUISCALAGUAS\AppData\Local\Python\pythoncore-3.11-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts saved_model_cli.exe, tf_upgrade_v2.exe, tflite_convert.exe and toco.exe are installed in 'c:\Users\JUSTINELUISCALAGUAS\AppData\Local\Python\pythoncore-3.11-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install numpy pandas matplotlib scipy librosa -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\JUSTINELUISCALAGUAS\AppData\Local\Python\pythoncore-3.11-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install seaborn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Speech Command Recognition — CNN + RL Threshold Tuning
# **Dataset**: Google Speech Commands V2 (Kaggle)
# **Model**: Mel Spectrogram → CNN (Keras/TensorFlow)
# **RL Agent**: Q-learning threshold tuner (minimize false rejects)
# **Metrics**: Accuracy, Macro-F1, Expected Cost

# %% [markdown]
# ## 1. Imports & Configuration

# %%
import os
import random
import sys
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display

try:
    import tensorflow as tf
    from tensorflow import keras
    from tensorflow.keras import layers
except ModuleNotFoundError as exc:
    raise ModuleNotFoundError(
        'TensorFlow is not installed or not compatible with this Python version. '
        'Use Python 3.11 or 3.12, then install tensorflow before rerunning this notebook.'
    ) from exc

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tqdm import tqdm

warnings.filterwarnings('ignore')

print('TensorFlow version:', tf.__version__)
print('GPU available:', len(tf.config.list_physical_devices('GPU')) > 0)

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
# Out:
# TensorFlow version: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPU available: False

# %%
# ── Paths ────────────────────────────────────────────────────────────
# Update DATA_DIR to wherever you extracted the dataset on your machine
# e.g. Windows: r'C:/Users/you/datasets/speech_commands_v0.02'
#      Mac/Linux: '/home/you/datasets/speech_commands_v0.02'
DATA_DIR = './speech_commands_v0.02'

# ── Audio config ──────────────────────────────────────────────────────
SAMPLE_RATE   = 16000   # all clips are 16kHz
CLIP_DURATION = 1.0     # seconds — pad/trim all clips to exactly 1s
N_SAMPLES     = int(SAMPLE_RATE * CLIP_DURATION)

# ── Mel Spectrogram config ───────────────────────────────────────────
N_MELS     = 64
HOP_LENGTH = 512
N_FFT      = 1024
FMAX       = 8000

# ── CNN training config ──────────────────────────────────────────────
BATCH_SIZE = 64
EPOCHS     = 100
LR         = 1e-3

# ── RL config ────────────────────────────────────────────────────────
# Cost matrix (asymmetric — false rejects cost more)
COST_FALSE_REJECT = 2.0   # penalty when the model misses a real command
COST_FALSE_ACCEPT = 1.0   # penalty when model accepts noise/wrong command

# Labels to keep (35 commands + _silence_ + _unknown_)
COMMANDS = [
    'yes', 'no', 'up', 'down', 'left', 'right',
    'on', 'off', 'stop', 'go',
    'zero', 'one', 'two', 'three', 'four',
    'five', 'six', 'seven', 'eight', 'nine',
    'bed', 'bird', 'cat', 'dog', 'happy',
    'house', 'marvin', 'sheila', 'tree', 'wow',
    'backward', 'forward', 'follow', 'learn', 'visual'
]

print(f'Commands to classify: {len(COMMANDS)}')
# Out:
# Commands to classify: 35

# %% [markdown]
# ## 2. Dataset Loading

# %%
def load_file_list(data_dir, commands):
    """
    Walk the dataset directory and collect (filepath, label) pairs.
    Uses the official validation_list.txt and testing_list.txt splits.
    """
    val_files  = set(open(os.path.join(data_dir, 'validation_list.txt')).read().splitlines())
    test_files = set(open(os.path.join(data_dir, 'testing_list.txt')).read().splitlines())

    records = []
    for cmd in commands:
        cmd_dir = os.path.join(data_dir, cmd)
        if not os.path.isdir(cmd_dir):
            continue
        for fname in os.listdir(cmd_dir):
            if not fname.endswith('.wav'):
                continue
            rel = f'{cmd}/{fname}'
            split = 'val' if rel in val_files else 'test' if rel in test_files else 'train'
            records.append({
                'path':  os.path.join(cmd_dir, fname),
                'label': cmd,
                'split': split
            })

    df = pd.DataFrame(records)
    print(df['split'].value_counts())
    return df

df = load_file_list(DATA_DIR, COMMANDS)
df.head()
# Out:
# split
# train    84843
# test     11005
# val       9981
# Name: count, dtype: int64
#                                                 path label  split
# 0  ./speech_commands_v0.02\yes\004ae714_nohash_0.wav   yes  train
# 1  ./speech_commands_v0.02\yes\004ae714_nohash_1.wav   yes  train
# 2  ./speech_commands_v0.02\yes\00970ce1_nohash_0.wav   yes  train
# 3  ./speech_commands_v0.02\yes\00f0204f_nohash_0.wav   yes  train
# 4  ./speech_commands_v0.02\yes\00f0204f_nohash_1.wav   yes  train

# %%
# Encode labels to integers
le = LabelEncoder()
df['label_id'] = le.fit_transform(df['label'])
NUM_CLASSES = len(le.classes_)
print(f'Classes ({NUM_CLASSES}):', le.classes_)
# Out:
# Classes (35): ['backward' 'bed' 'bird' 'cat' 'dog' 'down' 'eight' 'five' 'follow'
#  'forward' 'four' 'go' 'happy' 'house' 'learn' 'left' 'marvin' 'nine' 'no'
#  'off' 'on' 'one' 'right' 'seven' 'sheila' 'six' 'stop' 'three' 'tree'
#  'two' 'up' 'visual' 'wow' 'yes' 'zero']

# %% [markdown]
# ## 3. Feature Extraction — Mel Spectrograms

# %%
def load_wav(path, sr=SAMPLE_RATE, n_samples=N_SAMPLES):
    """Load a .wav file, resample, pad/trim to exactly n_samples."""
    y, _ = librosa.load(path, sr=sr, mono=True)
    if len(y) < n_samples:
        y = np.pad(y, (0, n_samples - len(y)))
    else:
        y = y[:n_samples]
    return y


def wav_to_melspec(y, sr=SAMPLE_RATE, n_mels=N_MELS,
                   n_fft=N_FFT, hop_length=HOP_LENGTH, fmax=FMAX):
    """
    Convert a waveform to a log-Mel spectrogram.
    Output shape: (n_mels, time_frames, 1)  — channel-last for Keras Conv2D
    """
    S = librosa.feature.melspectrogram(
        y=y, sr=sr, n_mels=n_mels,
        n_fft=n_fft, hop_length=hop_length, fmax=fmax
    )
    S_db = librosa.power_to_db(S, ref=np.max)  # log scale
    S_db = (S_db - S_db.mean()) / (S_db.std() + 1e-8)  # normalize
    return S_db[..., np.newaxis]  # add channel dim


def extract_features(df_split):
    """Extract mel-spectrograms for an entire split."""
    X, y = [], []
    for _, row in tqdm(df_split.iterrows(), total=len(df_split)):
        wav = load_wav(row['path'])
        spec = wav_to_melspec(wav)
        X.append(spec)
        y.append(row['label_id'])
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.int32)


# Visualise a few examples
fig, axes = plt.subplots(2, 4, figsize=(18, 6))
for ax, (_, row) in zip(axes.flat, df[df['split']=='train'].sample(8, random_state=SEED).iterrows()):
    wav = load_wav(row['path'])
    S = wav_to_melspec(wav)[..., 0]
    librosa.display.specshow(S, sr=SAMPLE_RATE, hop_length=HOP_LENGTH,
                             x_axis='time', y_axis='mel', ax=ax, fmax=FMAX)
    ax.set_title(row['label'], fontsize=11)
    ax.set_xlabel('')
plt.suptitle('Mel Spectrograms — 8 random training samples', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Extract all splits  (this takes a few minutes — ~105k files total)
print('Extracting training features...')
X_train, y_train = extract_features(df[df['split']=='train'])

print('Extracting validation features...')
X_val, y_val = extract_features(df[df['split']=='val'])

print('Extracting test features...')
X_test, y_test = extract_features(df[df['split']=='test'])

print(f'Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape}')
INPUT_SHAPE = X_train.shape[1:]  # (n_mels, time_frames, 1)
# Out:
# Extracting training features...
# 100%|██████████| 84843/84843 [09:11<00:00, 153.91it/s]
# Extracting validation features...
# 100%|██████████| 9981/9981 [01:08<00:00, 146.60it/s]
# Extracting test features...
# 100%|██████████| 11005/11005 [01:12<00:00, 150.89it/s]
# Train: (84843, 64, 32, 1), Val: (9981, 64, 32, 1), Test: (11005, 64, 32, 1)

# %% [markdown]
# ## 4. CNN Model

# %%
def build_cnn(input_shape, num_classes):
    """
    Compact CNN for mel-spectrogram classification.
    Architecture: 4x [Conv2D → BN → ReLU → MaxPool] → GlobalAvgPool → Dense
    """
    inputs = keras.Input(shape=input_shape, name='mel_spectrogram')

    x = inputs
    for filters in [32, 64, 128, 128]:
        x = layers.Conv2D(filters, (3, 3), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.MaxPooling2D((2, 2))(x)
        x = layers.Dropout(0.25)(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(num_classes, activation='softmax', name='probs')(x)

    model = keras.Model(inputs, outputs, name='SpeechCNN')
    return model


model = build_cnn(INPUT_SHAPE, NUM_CLASSES)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 25
#      21     model = keras.Model(inputs, outputs, name='SpeechCNN')
#      22     return model
# ---> 25 model = build_cnn(INPUT_SHAPE, NUM_CLASSES)
#      26 model.summary()
#
# NameError: name 'INPUT_SHAPE' is not defined

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=15,
                                   restore_best_weights=True, verbose=1),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                       patience=3, verbose=1),
    keras.callbacks.ModelCheckpoint('best_cnn.keras', monitor='val_accuracy',
                                     save_best_only=True, verbose=0)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 47s 34ms/step - accuracy: 0.4394 - loss: 1.9328 - val_accuracy: 0.7235 - val_loss: 0.9133 - learning_rate: 0.0010
# Epoch 2/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 46s 35ms/step - accuracy: 0.7237 - loss: 0.9075 - val_accuracy: 0.8508 - val_loss: 0.4994 - learning_rate: 0.0010
# Epoch 3/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.7829 - loss: 0.7138 - val_accuracy: 0.8868 - val_loss: 0.3747 - learning_rate: 0.0010
# Epoch 4/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 49s 37ms/step - accuracy: 0.8098 - loss: 0.6248 - val_accuracy: 0.8740 - val_loss: 0.4369 - learning_rate: 0.0010
# Epoch 5/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.8260 - loss: 0.5715 - val_accuracy: 0.8981 - val_loss: 0.3556 - learning_rate: 0.0010
# Epoch 6/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 48s 36ms/step - accuracy: 0.8383 - loss: 0.5306 - val_accuracy: 0.9064 - val_loss: 0.3231 - learning_rate: 0.0010
# Epoch 7/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.8483 - loss: 0.5008 - val_accuracy: 0.9141 - val_loss: 0.2940 - learning_rate: 0.0010
# Epoch 8/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8552 - loss: 0.4780 - val_accuracy: 0.9162 - val_loss: 0.2811 - learning_rate: 0.0010
# Epoch 9/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8614 - loss: 0.4599 - val_accuracy: 0.9236 - val_loss: 0.2625 - learning_rate: 0.0010
# Epoch 10/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8659 - loss: 0.4430 - val_accuracy: 0.9185 - val_loss: 0.2794 - learning_rate: 0.0010
# Epoch 11/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 45s 34ms/step - accuracy: 0.8688 - loss: 0.4285 - val_accuracy: 0.9256 - val_loss: 0.2463 - learning_rate: 0.0010
# Epoch 12/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 34ms/step - accuracy: 0.8741 - loss: 0.4109 - val_accuracy: 0.9244 - val_loss: 0.2514 - learning_rate: 0.0010
# Epoch 13/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8777 - loss: 0.4023 - val_accuracy: 0.9323 - val_loss: 0.2297 - learning_rate: 0.0010
# Epoch 14/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8822 - loss: 0.3914 - val_accuracy: 0.9298 - val_loss: 0.2318 - learning_rate: 0.0010
# Epoch 15/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8837 - loss: 0.3823 - val_accuracy: 0.9344 - val_loss: 0.2290 - learning_rate: 0.0010
# Epoch 16/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8859 - loss: 0.3735 - val_accuracy: 0.9291 - val_loss: 0.2330 - learning_rate: 0.0010
# Epoch 17/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8868 - loss: 0.3733 - val_accuracy: 0.9369 - val_loss: 0.2176 - learning_rate: 0.0010
# Epoch 18/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8908 - loss: 0.3592 - val_accuracy: 0.9360 - val_loss: 0.2139 - learning_rate: 0.0010
# Epoch 19/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8911 - loss: 0.3559 - val_accuracy: 0.9365 - val_loss: 0.2097 - learning_rate: 0.0010
# Epoch 20/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8933 - loss: 0.3503 - val_accuracy: 0.9373 - val_loss: 0.2047 - learning_rate: 0.0010
# Epoch 21/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8962 - loss: 0.3430 - val_accuracy: 0.9312 - val_loss: 0.2304 - learning_rate: 0.0010
# Epoch 22/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8977 - loss: 0.3386 - val_accuracy: 0.9388 - val_loss: 0.2088 - learning_rate: 0.0010
# Epoch 23/100
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8967 - loss: 0.3375
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.8982 - loss: 0.3317 - val_accuracy: 0.9349 - val_loss: 0.2112 - learning_rate: 0.0010
# Epoch 24/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 45s 34ms/step - accuracy: 0.9060 - loss: 0.3059 - val_accuracy: 0.9417 - val_loss: 0.1942 - learning_rate: 5.0000e-04
# Epoch 25/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9082 - loss: 0.2972 - val_accuracy: 0.9423 - val_loss: 0.1940 - learning_rate: 5.0000e-04
# Epoch 26/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9100 - loss: 0.2936 - val_accuracy: 0.9424 - val_loss: 0.1937 - learning_rate: 5.0000e-04
# Epoch 27/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9107 - loss: 0.2909 - val_accuracy: 0.9440 - val_loss: 0.1886 - learning_rate: 5.0000e-04
# Epoch 28/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9120 - loss: 0.2893 - val_accuracy: 0.9418 - val_loss: 0.1899 - learning_rate: 5.0000e-04
# Epoch 29/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9123 - loss: 0.2828 - val_accuracy: 0.9427 - val_loss: 0.1913 - learning_rate: 5.0000e-04
# Epoch 30/100
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9114 - loss: 0.2844
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9120 - loss: 0.2823 - val_accuracy: 0.9410 - val_loss: 0.1994 - learning_rate: 5.0000e-04
# Epoch 31/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9168 - loss: 0.2673 - val_accuracy: 0.9455 - val_loss: 0.1806 - learning_rate: 2.5000e-04
# Epoch 32/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 45s 34ms/step - accuracy: 0.9190 - loss: 0.2642 - val_accuracy: 0.9440 - val_loss: 0.1821 - learning_rate: 2.5000e-04
# Epoch 33/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9195 - loss: 0.2626 - val_accuracy: 0.9458 - val_loss: 0.1819 - learning_rate: 2.5000e-04
# Epoch 34/100
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9189 - loss: 0.2606
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9194 - loss: 0.2582 - val_accuracy: 0.9455 - val_loss: 0.1818 - learning_rate: 2.5000e-04
# Epoch 35/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9211 - loss: 0.2540 - val_accuracy: 0.9462 - val_loss: 0.1794 - learning_rate: 1.2500e-04
# Epoch 36/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9214 - loss: 0.2528 - val_accuracy: 0.9469 - val_loss: 0.1764 - learning_rate: 1.2500e-04
# Epoch 37/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9207 - loss: 0.2540 - val_accuracy: 0.9457 - val_loss: 0.1784 - learning_rate: 1.2500e-04
# Epoch 38/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9235 - loss: 0.2475 - val_accuracy: 0.9469 - val_loss: 0.1756 - learning_rate: 1.2500e-04
# Epoch 39/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9228 - loss: 0.2479 - val_accuracy: 0.9470 - val_loss: 0.1800 - learning_rate: 1.2500e-04
# Epoch 40/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9225 - loss: 0.2509 - val_accuracy: 0.9472 - val_loss: 0.1763 - learning_rate: 1.2500e-04
# Epoch 41/100
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9232 - loss: 0.2464
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9238 - loss: 0.2448 - val_accuracy: 0.9462 - val_loss: 0.1766 - learning_rate: 1.2500e-04
# Epoch 42/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9235 - loss: 0.2459 - val_accuracy: 0.9477 - val_loss: 0.1743 - learning_rate: 6.2500e-05
# Epoch 43/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9242 - loss: 0.2464 - val_accuracy: 0.9466 - val_loss: 0.1734 - learning_rate: 6.2500e-05
# Epoch 44/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9239 - loss: 0.2442 - val_accuracy: 0.9476 - val_loss: 0.1746 - learning_rate: 6.2500e-05
# Epoch 45/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9243 - loss: 0.2428 - val_accuracy: 0.9478 - val_loss: 0.1735 - learning_rate: 6.2500e-05
# Epoch 46/100
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9241 - loss: 0.2427
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9249 - loss: 0.2415 - val_accuracy: 0.9472 - val_loss: 0.1747 - learning_rate: 6.2500e-05
# Epoch 47/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9250 - loss: 0.2432 - val_accuracy: 0.9473 - val_loss: 0.1751 - learning_rate: 3.1250e-05
# Epoch 48/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9250 - loss: 0.2396 - val_accuracy: 0.9482 - val_loss: 0.1735 - learning_rate: 3.1250e-05
# Epoch 49/100
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9260 - loss: 0.2396
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9262 - loss: 0.2386 - val_accuracy: 0.9481 - val_loss: 0.1741 - learning_rate: 3.1250e-05
# Epoch 50/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.9265 - loss: 0.2401 - val_accuracy: 0.9477 - val_loss: 0.1741 - learning_rate: 1.5625e-05
# Epoch 51/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 45s 34ms/step - accuracy: 0.9250 - loss: 0.2419 - val_accuracy: 0.9479 - val_loss: 0.1739 - learning_rate: 1.5625e-05
# Epoch 52/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9242 - loss: 0.2423
# Epoch 52: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 51s 38ms/step - accuracy: 0.9259 - loss: 0.2387 - val_accuracy: 0.9473 - val_loss: 0.1735 - learning_rate: 1.5625e-05
# Epoch 53/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 47s 36ms/step - accuracy: 0.9263 - loss: 0.2376 - val_accuracy: 0.9475 - val_loss: 0.1735 - learning_rate: 7.8125e-06
# Epoch 54/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 49s 37ms/step - accuracy: 0.9261 - loss: 0.2363 - val_accuracy: 0.9476 - val_loss: 0.1736 - learning_rate: 7.8125e-06
# Epoch 55/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9250 - loss: 0.2406
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.9264 - loss: 0.2367 - val_accuracy: 0.9477 - val_loss: 0.1736 - learning_rate: 7.8125e-06
# Epoch 56/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 48s 36ms/step - accuracy: 0.9260 - loss: 0.2381 - val_accuracy: 0.9475 - val_loss: 0.1735 - learning_rate: 3.9063e-06
# Epoch 57/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 48s 36ms/step - accuracy: 0.9250 - loss: 0.2385 - val_accuracy: 0.9474 - val_loss: 0.1736 - learning_rate: 3.9063e-06
# Epoch 58/100
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9240 - loss: 0.2406
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 51s 39ms/step - accuracy: 0.9256 - loss: 0.2375 - val_accuracy: 0.9476 - val_loss: 0.1736 - learning_rate: 3.9063e-06
# Epoch 59/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 49s 37ms/step - accuracy: 0.9273 - loss: 0.2360 - val_accuracy: 0.9475 - val_loss: 0.1737 - learning_rate: 1.9531e-06
# Epoch 60/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 49s 37ms/step - accuracy: 0.9263 - loss: 0.2381 - val_accuracy: 0.9477 - val_loss: 0.1738 - learning_rate: 1.9531e-06
# Epoch 61/100
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9253 - loss: 0.2377
# Epoch 61: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 50s 38ms/step - accuracy: 0.9260 - loss: 0.2366 - val_accuracy: 0.9474 - val_loss: 0.1736 - learning_rate: 1.9531e-06
# Epoch 62/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 47s 36ms/step - accuracy: 0.9251 - loss: 0.2392 - val_accuracy: 0.9477 - val_loss: 0.1735 - learning_rate: 9.7656e-07
# Epoch 63/100
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.9257 - loss: 0.2404 - val_accuracy: 0.9478 - val_loss: 0.1736 - learning_rate: 9.7656e-07
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 48.

# %%
# Training curves
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))

ax1.plot(history.history['accuracy'],     label='Train')
ax1.plot(history.history['val_accuracy'], label='Val')
ax1.set_title('Accuracy'); ax1.legend(); ax1.set_xlabel('Epoch')

ax2.plot(history.history['loss'],     label='Train')
ax2.plot(history.history['val_loss'], label='Val')
ax2.set_title('Loss'); ax2.legend(); ax2.set_xlabel('Epoch')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Baseline Evaluation (default threshold = 0.5)

# %%
# Get softmax probabilities on the test set
probs_test = model.predict(X_test, batch_size=BATCH_SIZE, verbose=1)  # shape: (N, NUM_CLASSES)

def evaluate_with_threshold(probs, y_true, threshold, cost_fr=COST_FALSE_REJECT,
                            cost_fa=COST_FALSE_ACCEPT, label_names=None):
    """
    Evaluate predictions using a confidence threshold.
    
    A prediction is accepted only if max(probs) >= threshold.
    Rejected samples (max prob < threshold) are treated as 'unknown' — 
    they count as false rejects if the true label was a known command.
    
    Returns dict of metrics.
    """
    max_probs  = probs.max(axis=1)           # confidence of top prediction
    pred_class = probs.argmax(axis=1)        # predicted class index

    accepted = max_probs >= threshold
    rejected = ~accepted

    # Final predictions: accepted → predicted class, rejected → -1 (unknown)
    final_pred = np.where(accepted, pred_class, -1)

    # Accuracy (only on accepted samples)
    correct   = (final_pred == y_true) & accepted
    accuracy  = correct.sum() / len(y_true)

    # Macro-F1 (on accepted samples only)
    mask = accepted
    macro_f1 = f1_score(y_true[mask], pred_class[mask],
                        average='macro', zero_division=0) if mask.any() else 0.0

    # False reject rate: how many real commands were rejected
    false_rejects = rejected.sum()  # all rejections are false rejects (true label is a command)
    fr_rate = false_rejects / len(y_true)

    # False accept rate: accepted but wrong class
    false_accepts = ((final_pred != y_true) & accepted).sum()
    fa_rate = false_accepts / len(y_true)

    # Expected cost
    expected_cost = (false_rejects * cost_fr + false_accepts * cost_fa) / len(y_true)

    return {
        'threshold':     threshold,
        'accuracy':      accuracy,
        'macro_f1':      macro_f1,
        'fr_rate':       fr_rate,
        'fa_rate':       fa_rate,
        'expected_cost': expected_cost,
        'accept_rate':   accepted.mean()
    }


baseline = evaluate_with_threshold(probs_test, y_test, threshold=0.5)
print('── Baseline (threshold=0.5) ───────────────')
for k, v in baseline.items():
    print(f'  {k:<18}: {v:.4f}')
# Out:
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# ── Baseline (threshold=0.5) ───────────────
#   threshold         : 0.5000
#   accuracy          : 0.9320
#   macro_f1          : 0.9594
#   fr_rate           : 0.0326
#   fa_rate           : 0.0353
#   expected_cost     : 0.1006
#   accept_rate       : 0.9674

# %%
# Confusion matrix at baseline
pred_baseline = np.where(probs_test.max(axis=1) >= 0.5, probs_test.argmax(axis=1), -1)
mask = pred_baseline != -1

cm = confusion_matrix(y_test[mask], pred_baseline[mask])
fig, ax = plt.subplots(figsize=(16, 14))
sns.heatmap(cm, annot=False, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_, ax=ax)
ax.set_xlabel('Predicted'); ax.set_ylabel('True')
ax.set_title('Confusion Matrix — Baseline (threshold=0.5)')
plt.tight_layout()
plt.show()

print(classification_report(y_test[mask], pred_baseline[mask],
                             target_names=le.classes_, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#     backward       0.98      0.97      0.98       162
#          bed       0.92      0.92      0.92       198
#         bird       0.96      0.94      0.95       174
#          cat       0.95      0.98      0.96       181
#          dog       0.95      0.94      0.94       208
#         down       0.96      0.93      0.94       389
#        eight       0.98      0.98      0.98       393
#         five       0.96      0.98      0.97       437
#       follow       0.94      0.92      0.93       159
#      forward       0.92      0.89      0.90       148
#         four       0.94      0.96      0.95       380
#           go       0.93      0.94      0.93       386
#        happy       0.96      0.96      0.96       196
#        house       0.99      0.96      0.98       187
#        learn       0.93      0.88      0.91       145
#         left       0.95      0.99      0.97       401
#       marvin       1.00      0.98      0.99       187
#         nine       0.97      0.97      0.97       400
#           no       0.94      0.96      0.95       396
#          off       0.97      0.98      0.97       386
#           on       0.96      0.98      0.97       379
#          one       0.98      0.97      0.97       389
#        right       0.99      0.96      0.98       385
#        seven       0.98      0.99      0.99       400
#       sheila       0.97      0.98      0.98       206
#          six       1.00      0.99      0.99       386
#         stop       0.99      0.99      0.99       403
#        three       0.94      0.95      0.94       393
#         tree       0.93      0.87      0.90       183
#          two       0.96      0.97      0.97       418
#           up       0.98      0.97      0.97       410
#       visual       0.95      0.96      0.96       161
#          wow       0.97      0.95      0.96       198
#          yes       0.99      0.98      0.98       414
#         zero       0.99      0.97      0.98       408
#
#     accuracy                           0.96     10646
#    macro avg       0.96      0.96      0.96     10646
# weighted avg       0.96      0.96      0.96     10646

# %% [markdown]
# ## 6. RL Threshold Tuning Agent
#
# We model threshold selection as a **1-D continuous bandit / Q-learning problem**:
# - **State**: discretized confidence threshold in [0, 1]
# - **Action**: lower / keep / raise threshold
# - **Reward**: negative expected cost (we want to minimise false rejects → lower cost)
#
# The agent observes a mini-batch of validation predictions, computes the expected cost at the current threshold, and updates a Q-table.

# %%
class ThresholdRLAgent:
    """
    Tabular Q-learning agent that tunes a decision threshold
    to minimise expected cost under asymmetric error penalties.

    State  : discretized threshold index in {0, 1, ..., n_states-1}
    Actions: 0=lower, 1=keep, 2=raise  (step size = 1 / n_states)
    Reward : -expected_cost (negative because RL maximises reward)
    """

    def __init__(self, n_states=20, alpha=0.1, gamma=0.9,
                 epsilon=0.3, epsilon_decay=0.995, epsilon_min=0.01,
                 cost_fr=COST_FALSE_REJECT, cost_fa=COST_FALSE_ACCEPT):
        self.n_states    = n_states
        self.alpha       = alpha        # learning rate
        self.gamma       = gamma        # discount factor
        self.epsilon     = epsilon      # exploration rate
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.cost_fr     = cost_fr
        self.cost_fa     = cost_fa

        # Q-table: shape (n_states, 3)
        self.Q = np.zeros((n_states, 3))

        # Start at middle threshold
        self.state = n_states // 2

    @property
    def threshold(self):
        """Current threshold value in [0, 1]."""
        return self.state / self.n_states

    def _next_state(self, action):
        if action == 0:   # lower
            return max(0, self.state - 1)
        elif action == 2: # raise
            return min(self.n_states - 1, self.state + 1)
        return self.state # keep

    def _compute_reward(self, probs_batch, labels_batch):
        """Reward = negative expected cost on the current mini-batch."""
        metrics = evaluate_with_threshold(
            probs_batch, labels_batch, self.threshold,
            self.cost_fr, self.cost_fa
        )
        return -metrics['expected_cost']

    def select_action(self):
        """Epsilon-greedy action selection."""
        if np.random.rand() < self.epsilon:
            return np.random.randint(3)
        return np.argmax(self.Q[self.state])

    def step(self, probs_batch, labels_batch):
        """One RL step: select action → transition → observe reward → update Q."""
        action     = self.select_action()
        next_state = self._next_state(action)

        # Observe reward at NEW state
        old_state   = self.state
        self.state  = next_state
        reward      = self._compute_reward(probs_batch, labels_batch)

        # Q-update
        td_target = reward + self.gamma * np.max(self.Q[next_state])
        td_error  = td_target - self.Q[old_state, action]
        self.Q[old_state, action] += self.alpha * td_error

        # Decay exploration
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

        return reward, self.threshold


print('RL agent defined.')
# Out:
# RL agent defined.

# %%
# Use validation set to train the RL agent
probs_val = model.predict(X_val, batch_size=BATCH_SIZE, verbose=0)

agent = ThresholdRLAgent(n_states=20, alpha=0.1, gamma=0.9, epsilon=0.5)

EPISODES   = 300
BATCH_SIZE_RL = 256    # samples per episode

reward_history   = []
threshold_history = []

for ep in range(EPISODES):
    # Sample a mini-batch from validation
    idx = np.random.choice(len(probs_val), size=BATCH_SIZE_RL, replace=False)
    reward, thr = agent.step(probs_val[idx], y_val[idx])
    reward_history.append(reward)
    threshold_history.append(thr)

optimal_threshold = agent.threshold
print(f'RL-tuned threshold: {optimal_threshold:.3f}  (started at 0.500)')
# Out:
# RL-tuned threshold: 0.350  (started at 0.500)

# %%
# Plot RL training progress
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))

ax1.plot(reward_history, alpha=0.7, color='steelblue')
ax1.plot(pd.Series(reward_history).rolling(20).mean(), color='red', lw=2, label='20-ep rolling mean')
ax1.set_title('RL Agent — Episode Reward (= -Expected Cost)')
ax1.set_xlabel('Episode'); ax1.legend()

ax2.plot(threshold_history, alpha=0.7, color='darkorange')
ax2.axhline(optimal_threshold, color='red', lw=2, linestyle='--',
            label=f'Final threshold = {optimal_threshold:.3f}')
ax2.set_title('Threshold Over Training')
ax2.set_xlabel('Episode'); ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Final Evaluation — Baseline vs RL-tuned Threshold

# %%
# Sweep thresholds to visualise the trade-off curve
thresholds = np.linspace(0.01, 0.99, 50)
results = [evaluate_with_threshold(probs_test, y_test, t) for t in thresholds]
results_df = pd.DataFrame(results)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for ax, metric, color in zip(axes,
                              ['macro_f1', 'fr_rate', 'expected_cost'],
                              ['steelblue', 'crimson', 'darkorange']):
    ax.plot(results_df['threshold'], results_df[metric], color=color, lw=2)
    ax.axvline(0.5, color='gray', linestyle='--', alpha=0.6, label='Baseline (0.5)')
    ax.axvline(optimal_threshold, color='black', linestyle='--', lw=2,
               label=f'RL-tuned ({optimal_threshold:.2f})')
    ax.set_title(metric.replace('_', ' ').title())
    ax.set_xlabel('Threshold'); ax.legend()

plt.suptitle('Threshold Sweep on Test Set', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Side-by-side comparison
rl_result = evaluate_with_threshold(probs_test, y_test, optimal_threshold)

compare_df = pd.DataFrame([baseline, rl_result]).set_index('threshold').T
compare_df.columns = [f'Baseline (thr=0.50)', f'RL-tuned (thr={optimal_threshold:.2f})']
print('\n── Test Set Results ──────────────────────────────────────────')
print(compare_df.to_string(float_format=lambda x: f'{x:.4f}'))
# Out:
# ── Test Set Results ──────────────────────────────────────────
#                Baseline (thr=0.50)  RL-tuned (thr=0.35)
# accuracy                    0.9320               0.9377
# macro_f1                    0.9594               0.9503
# fr_rate                     0.0326               0.0179
# fa_rate                     0.0353               0.0444
# expected_cost               0.1006               0.0802
# accept_rate                 0.9674               0.9821

# %%
# Bar chart comparison
metrics_to_plot = ['accuracy', 'macro_f1', 'fr_rate', 'fa_rate', 'expected_cost']
x = np.arange(len(metrics_to_plot))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 5))
bars1 = ax.bar(x - width/2, [baseline[m]    for m in metrics_to_plot], width,
               label='Baseline (0.50)', color='steelblue', alpha=0.8)
bars2 = ax.bar(x + width/2, [rl_result[m] for m in metrics_to_plot], width,
               label=f'RL-tuned ({optimal_threshold:.2f})', color='darkorange', alpha=0.8)

ax.set_xticks(x)
ax.set_xticklabels([m.replace('_', ' ').title() for m in metrics_to_plot])
ax.set_title('Baseline vs RL-Tuned Threshold — Test Set Metrics')
ax.legend()
ax.bar_label(bars1, fmt='%.3f', padding=3, fontsize=9)
ax.bar_label(bars2, fmt='%.3f', padding=3, fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Ethics Audit — Per-Speaker Fairness
#
# The Google Speech Commands V2 dataset includes speaker IDs. We check whether accuracy / false-reject rate is consistent across speakers to surface potential accent/dialect bias.

# %%
# Build a test dataframe with predictions
df_test = df[df['split']=='test'].copy().reset_index(drop=True)

# Extract speaker ID from filename (format: speakerid_nonce.wav)
df_test['speaker'] = df_test['path'].apply(
    lambda p: os.path.basename(p).split('_')[0]
)

# Attach predictions
df_test['pred_class']  = probs_test.argmax(axis=1)
df_test['confidence']  = probs_test.max(axis=1)
df_test['accepted']    = df_test['confidence'] >= optimal_threshold
df_test['correct']     = df_test['pred_class'] == df_test['label_id']
df_test['false_reject'] = ~df_test['accepted']

# Per-speaker summary (speakers with >= 10 test samples)
speaker_stats = df_test.groupby('speaker').agg(
    n_samples    = ('label_id', 'count'),
    accuracy     = ('correct',  'mean'),
    fr_rate      = ('false_reject', 'mean')
).query('n_samples >= 10').sort_values('fr_rate', ascending=False)

print(f'Speakers with >=10 test samples: {len(speaker_stats)}')
print(speaker_stats.head(10).to_string())
# Out:
# Speakers with >=10 test samples: 224
#           n_samples  accuracy   fr_rate
# speaker
# 8ea6dec6         32  0.125000  0.968750
# 475b61f1         23  0.391304  0.739130
# 3659fc1c         34  0.382353  0.617647
# 220ee1ef         17  0.352941  0.588235
# c9e251d2         30  0.500000  0.433333
# dcb57584         12  0.333333  0.416667
# 82d0d3ba         18  0.611111  0.333333
# a9f54d8d         14  0.357143  0.285714
# dfdabe19         28  0.642857  0.285714
# 2005ca25         27  0.444444  0.259259

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))

ax1.hist(speaker_stats['accuracy'], bins=20, color='steelblue', edgecolor='white')
ax1.axvline(speaker_stats['accuracy'].mean(), color='red', linestyle='--',
            label=f'Mean = {speaker_stats["accuracy"].mean():.3f}')
ax1.set_title('Per-Speaker Accuracy Distribution')
ax1.set_xlabel('Accuracy'); ax1.legend()

ax2.hist(speaker_stats['fr_rate'], bins=20, color='darkorange', edgecolor='white')
ax2.axvline(speaker_stats['fr_rate'].mean(), color='red', linestyle='--',
            label=f'Mean = {speaker_stats["fr_rate"].mean():.3f}')
ax2.set_title('Per-Speaker False Reject Rate Distribution')
ax2.set_xlabel('False Reject Rate'); ax2.legend()

plt.suptitle('Fairness Audit — Spread Across Speakers', fontsize=13)
plt.tight_layout()
plt.show()

print(f'\nAccuracy std across speakers:     {speaker_stats["accuracy"].std():.4f}')
print(f'False reject rate std across speakers: {speaker_stats["fr_rate"].std():.4f}')
print('\nNote: high std indicates potential accent/dialect fairness concerns.')
# Out:
# Accuracy std across speakers:     0.1448
# False reject rate std across speakers: 0.1143
#
# Note: high std indicates potential accent/dialect fairness concerns.

# %% [markdown]
# ## 9. Summary
#
# | Component | Details |
# |---|---|
# | **Feature** | Log-Mel Spectrogram (64 mel bins, 1024-pt FFT) |
# | **Model** | 4-block Conv2D + GlobalAvgPool + Dense |
# | **RL Agent** | Tabular Q-learning, 20 threshold states, ε-greedy |
# | **Cost** | FR penalty=2.0, FA penalty=1.0 (false-reject minimisation) |
# | **Metrics** | Accuracy, Macro-F1, Expected Cost, FR rate, FA rate |
# | **Ethics** | Per-speaker accuracy and FR-rate fairness audit |
#
# ### Next Steps (Stretch Goals)
# - **Noise robustness**: augment training with `librosa` noise injection / SpecAugment
# - **On-device inference**: convert model to TFLite with `tf.lite.TFLiteConverter`
# - **Deeper RL**: replace tabular Q-learning with a small DQN over a continuous threshold space

# %% [markdown]
# ## 5. Live User Inference (Mic / Upload)
# Test the model natively! Use the microphone to record a 1-second interval or upload an existing `.wav` file.

# %%
# Install dependencies for audio recording if missing
# %pip install sounddevice -q

import sounddevice as sd
from scipy.io.wavfile import write as write_wav
import IPython.display as ipd
import time
import os
import queue
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# ==============================================================================
# THE NLP COMPONENT
# ==============================================================================
class NLPIntentMapper:
    """
    A rule-based NLP Intent Classifier that maps raw acoustic predictions 
    from the CNN into semantic Intents, Actions, and Categories.
    """
    def __init__(self):
        self.intent_map = {
            'stop':  {'intent': 'NAVIGATION',    'action': 'Halt current movement',     'category': 'Motion Control'},
            'go':    {'intent': 'NAVIGATION',    'action': 'Initiate forward movement', 'category': 'Motion Control'},
            'left':  {'intent': 'NAVIGATION',    'action': 'Rotate left 90 degrees',    'category': 'Motion Control'},
            'right': {'intent': 'NAVIGATION',    'action': 'Rotate right 90 degrees',   'category': 'Motion Control'},
            'on':    {'intent': 'POWER_CONTROL', 'action': 'Power on system',           'category': 'Device Management'},
            'off':   {'intent': 'POWER_CONTROL', 'action': 'Power down system',         'category': 'Device Management'},
            'yes':   {'intent': 'CONFIRMATION',  'action': 'Proceed with operation',    'category': 'System Status'},
            'no':    {'intent': 'CANCELLATION',  'action': 'Abort operation',           'category': 'System Status'},
            'uncertain': {'intent': 'UNKNOWN',   'action': 'Request clarification',     'category': 'Error Handling'}
        }
    
    def classify_intent(self, text):
        t = text.lower().strip()
        if 'uncertain' in t:
            return self.intent_map['uncertain']
        return self.intent_map.get(t, self.intent_map['uncertain'])

nlp_classifier = NLPIntentMapper()
# ==============================================================================

def predict_audio(filepath):
    # Load and preprocess
    wav = load_wav(filepath)
    spec = wav_to_melspec(wav)
    
    # Acoustic Inference on single sample
    probs = model.predict(np.array([spec]), verbose=0)[0]
    max_prob = probs.max()
    pred_idx = probs.argmax()
    
    # RL thresholding check
    if max_prob >= optimal_threshold:
        pred_label = le.inverse_transform([pred_idx])[0]
    else:
        pred_label = "Uncertain (Below RL Threshold)"
    
    # --- NLP Intent Routing ---
    nlp_result = nlp_classifier.classify_intent(pred_label)
    # --------------------------
    
    # Calculate Top 3 Indices
    top_3_idx = np.argsort(probs)[-3:][::-1]
    
    # ── CUSTOM PRINT FORMATTING ──
    print(f"\n✅  COMMAND    : {pred_label.upper()}")
    print(f"      CONFIDENCE : {max_prob * 100:.1f}%\n")
    
    print(f"  🧠  INTENT     : {nlp_result['intent']}")
    print(f"      ACTION     : {nlp_result['action']}")
    print(f"      CATEGORY   : {nlp_result['category']}\n")
    
    print("  Top 3 predictions:")
    for i, idx in enumerate(top_3_idx, 1):
        word = le.inverse_transform([idx])[0]
        prob_pct = probs[idx] * 100
        # Format padding so it lines up wonderfully
        print(f"    {i}. {word:<12} {prob_pct:>5.1f}%")
        
def test_microphone_manual():
    print('\n🎙️ Get ready to speak...')
    time.sleep(1)
    
    q = queue.Queue()
    def callback(indata, frames, time, status):
        q.put(indata.copy())
    
    stream = sd.InputStream(samplerate=16000, channels=1, dtype='float32', callback=callback)
    with stream:
        print('🔴 RECORDING... SPEAK NOW!')
        input('>>> Press [Enter] in the prompt box at the top to STOP recording <<<')
        
    print('\n✅ Recording stopped! Saving...')
    audio_data = []
    while not q.empty():
        audio_data.append(q.get())
        
    audio_blocks = np.concatenate(audio_data, axis=0)
    write_wav('live_mic.wav', 16000, audio_blocks)
    
    print('✅ Recording saved! Playing back:')
    ipd.display(ipd.Audio('live_mic.wav'))
    predict_audio('live_mic.wav')

def test_file(filepath):
    if not os.path.exists(filepath):
        print(f'\n❌ Error: File not found ({filepath})')
        return
    print(f'\n✅ Loaded {filepath}! Playing back:')
    ipd.display(ipd.Audio(filepath))
    predict_audio(filepath)

def user_inference():
    print('========================================')
    print('Choose your input method:')
    print('1. Record live from Microphone (Press [Enter] to Stop)')
    print('2. Select an existing .wav audio file (Opens File Browser)')
    print('========================================')
    
    choice = input('Type 1 or 2 and press Enter: ').strip()
    
    if choice == '1':
        test_microphone_manual()
    elif choice == '2':
        import tkinter as tk
        from tkinter import filedialog
        
        print('\n📂 Opening file browser... Please select your .wav file (Check your taskbar if it does not pop up!)')
        
        # Open a native Windows file explorer GUI securely!
        root = tk.Tk()
        root.withdraw()
        root.attributes('-topmost', True)
        
        filepath = filedialog.askopenfilename(
            title="Select Audio File",
            filetypes=(("WAV files", "*.wav"), ("All files", "*.*"))
        )
        root.destroy()
        
        if filepath:
            test_file(filepath)
        else:
            print('\n❌ No file selected. Operation cancelled.')
    else:
        print('\n❌ Invalid choice. Please run the cell again.')

# Turn on the interactive prompt!
user_inference()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ========================================
# Choose your input method:
# 1. Record live from Microphone (Press [Enter] to Stop)
# 2. Select an existing .wav audio file (Opens File Browser)
# ========================================
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# 🎙️ Get ready to speak...
# 🔴 RECORDING... SPEAK NOW!
#
# ✅ Recording stopped! Saving...
# ✅ Recording saved! Playing back:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ✅  COMMAND    : UNCERTAIN (BELOW RL THRESHOLD)
#       CONFIDENCE : 9.0%
#
#   🧠  INTENT     : UNKNOWN
#       ACTION     : Request clarification
#       CATEGORY   : Error Handling
#
#   Top 3 predictions:
#     1. off            9.0%
#     2. on             7.5%
#     3. bed            6.0%
